# %%
from pymilvus import MilvusClient
client = MilvusClient("./milvus_demo.db")

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]

# %%
import couchdb

# %%
import couchdb

# CouchDB credentials
COUCHDB_URL = "http://127.0.0.1:5984"
USERNAME = "admin"
PASSWORD = "admin"

# Connect to CouchDB server
couch = couchdb.Server(f"http://{USERNAME}:{PASSWORD}@127.0.0.1:5984/")

# Test connection
print("Connected to CouchDB. Databases:", list(server))
# Out:
# Connected to CouchDB. Databases: ['testdb']

# %%
db = couch.create('test')

# %%
doc = {'foo': 'bar'}
db.save(doc)
# Out:
# ('0c04ab4d6c3445bf1f82d66dd70004a7', '1-4c6114c65e295552ab1019e2b046b10e')

# %%
doc
# Out:
# {'foo': 'bar',
#  '_id': '0c04ab4d6c3445bf1f82d66dd70004a7',
#  '_rev': '1-4c6114c65e295552ab1019e2b046b10e'}

# %%
db['0c04ab4d6c3445bf1f82d66dd70004a7']
# Out:
# <Document '0c04ab4d6c3445bf1f82d66dd70004a7'@'1-4c6114c65e295552ab1019e2b046b10e' {'foo': 'bar'}>

# %%
for id in db:
    print(id)
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFound                          Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 for id in db:
#       2     print(id)
#
# File ~/miniconda3/envs/ocr_system/lib/python3.12/site-packages/couchdb/client.py:401, in Database.__iter__(self)
#     399 def __iter__(self):
#     400     """Return the IDs of all documents in the database."""
# --> 401     return iter([item.id for item in self.view('_all_docs')])
#
# File ~/miniconda3/envs/ocr_system/lib/python3.12/site-packages/couchdb/client.py:1358, in ViewResults.__iter__(self)
#    1357 def __iter__(self):
# -> 1358     return iter(self.rows)
#
# File ~/miniconda3/envs/ocr_system/lib/python3.12/site-packages/couchdb/client.py:1378, in ViewResults.rows(self)
#    1373 """The list of rows returned by the view.
#    1374
#    1375 :rtype: `list`
#    1376 """
#    1377 if self._rows is None:
# -> 1378     self._fetch()
# ...

# %%
db.delete(doc)

# %%
couch.delete('test')

# %%
from paddleocr import PaddleOCR, draw_ocr

# Also switch the language by modifying the lang parameter
ocr = PaddleOCR(lang="arabic") # The model file will be downloaded automatically when executed for the first time
img_path =r'/home/azooz/mydisk/ocr_invoices/UAE-VAT-Invoice-Template-Arabic.jpg'
result = ocr.ocr(img_path)
# Recognition and detection can be performed separately through parameter control
# result = ocr.ocr(img_path, det=False)  Only perform recognition
# result = ocr.ocr(img_path, rec=False)  Only perform detection
# Print detection frame and recognition result
for line in result:
    print(line)

# Visualization
from PIL import Image
image = Image.open(img_path).convert('RGB')
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]
scores = [line[1][1] for line in result]
# im_show = draw_ocr(image, boxes, txts, scores)
# im_show = Image.fromarray(im_show)
# im_show.save('result.jpg')

print(txts)
# Out:
# [2025/03/05 11:18:57] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/azooz/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/azooz/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2
# ...

# %%
for i in result[0]: 
    print(i[-1][1], i[-1][0][::-1])
# Out:
# 0.9876601099967957 ذمم
# 0.9999463558197021 التجار
# 0.9693907499313354 مشرق
# 0.9649572372436523 إدراج
# 0.8423769474029541 32
# 0.9491803646087646 مبنى
# 0.9764666557312012 CBA
# 0.995306134223938 شارع ديف
# 0.901059627532959 IHG
# 0.9994800090789795 الشعار
# 0.9791313409805298 :NRT
# 0.7770372033119202 654321ED21A
# 0.9998831152915955 الضرائب
# 0.9307284951210022 فاتورة
# 0.6932443380355835 1202/72/21
# 0.9128085970878601 تاريخ
# 0.8466163277626038 رقم الففاتورة:
# 0.6171675324440002 توtiderCide
# 0.7579431533813477 معرف شط   شط10
# 0.6544024348258972 5
# 0.8718063831329346 أيام
# 0.8428596258163452 الأسفات
# 0.926752507686615 أجهزة كمبيوتر
# 0.8507524132728577 اسم
# 0.8184126615524292 2202/11/1
# 0.9377704858779907 الاستحقاق:
# 0.9121875762939453 تاريخ
# 0.896264910697937 عنوان :شارع ديف1
# 0.8235570788383484 654321ED21EA
# 0.9897472262382507 NRT
# 0.9847784042358398 العميل
# 0.9207403659820557 مبلغ
# 0.9464437365531921 ضريبه
# 0.8699676394462585 القيمة للضريبة
# ...
